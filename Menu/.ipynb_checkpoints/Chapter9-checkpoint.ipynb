# %% [markdown]
# # Chapter9 - Unsupervised Learning
# ## Setup

# %%
import sys, os, sklearn
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
np.random.seed(42)
# %matplotlib inline
mpl.rc('axes', labelsize = 14)
mpl.rc('xtick', labelsize = 12)
mpl.rc('ytick', labelsize = 12)
PROJECT_ROOT_DIR, CHAPTER_ID = ".", "unsupervised_learning"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok = True)
def save_fig(fig_id, tight_layout = True, fig_extension = "png", resolution = 300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format = fig_extension, dpi = resolution)
import warnings
warnings.filterwarnings(action = "ignore", message = "^internal gelsd")

# %% [markdown]
# ## Clustering
# ### Introduction - Classification vs. Clustering

# %%
from sklearn.datasets import load_iris
data = load_iris()
X, y = data.data, data.target
display(data.target_names)
plt.figure(figsize=(9, 3.5))

plt.subplot(121)
plt.plot(X[y==0, 2], X[y==0, 3], "yo", label="Iris setosa")
plt.plot(X[y==1, 2], X[y==1, 3], "bs", label="Iris versicolor")
plt.plot(X[y==2, 2], X[y==2, 3], "g^", label="Iris virginica")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(fontsize=12)

plt.subplot(122)
plt.scatter(X[:, 2], X[:, 3], c="k", marker=".")
plt.xlabel("Petal length", fontsize=14)
plt.tick_params(labelleft=False)

save_fig("classification_vs_clustering_plot")
plt.show()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')
# Saving figure classification_vs_clustering_plot

# %%
from sklearn.mixture  import GaussianMixture
y_pred = GaussianMixture(n_components = 3, random_state = 42).fit(X).predict(X)
mapping = np.array([2, 0, 1])
y_pred = np.array([mapping[cluster_id] for cluster_id in y_pred])
display(np.sum(y_pred == y) / len(y_pred))
plt.plot(X[y_pred==0, 2], X[y_pred==0, 3], "yo", label="Cluster 1")
plt.plot(X[y_pred==1, 2], X[y_pred==1, 3], "bs", label="Cluster 2")
plt.plot(X[y_pred==2, 2], X[y_pred==2, 3], "g^", label="Cluster 3")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()
# Out:
# 0.9666666666666667

# %% [markdown]
# ## K-means
# ### Prepare the training set

# %%
from sklearn.datasets import make_blobs
blob_centers = np.array(
    [[0.2, 2.3],
     [-1.5, 2.3],
     [-2.8, 1.8],
     [-2.8, 2.8],
     [-2.8, 1.3]]
)
blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])
X, y = make_blobs(n_samples = 2000, centers = blob_centers, \
                  cluster_std = blob_std, random_state = 7)
def plot_clusters(X, y = None):
    plt.scatter(X[:, 0], X[:, 1], c = y, s = 1)
    plt.xlabel("$x_1$", fontsize = 14)
    plt.ylabel("$x_2$", fontsize = 14, rotation = 0)
plt.figure(figsize = (8, 4))
plot_clusters(X)
save_fig("blobs_plot")
plt.show()
# Out:
# Saving figure blobs_plot

# %% [markdown]
# ### Fit and Predict

# %%
from sklearn.cluster import KMeans
k = 5
kmeans = KMeans(n_clusters = k, random_state = 42)
y_pred = kmeans.fit_predict(X)
display(y_pred)
display(y_pred is kmeans.labels_)
# KMeans instance preserved the labels of the instances it was trained on.
display(kmeans.labels_)
display(kmeans.cluster_centers_)
X_new = np.array([[0, 2], [3, 2], [-3, 3], [-3, 2.5]])
display(kmeans.predict(X_new))
# Out:
# array([4, 0, 1, ..., 2, 1, 0])
# True
# array([4, 0, 1, ..., 2, 1, 0])
# array([[-2.80389616,  1.80117999],
#        [ 0.20876306,  2.25551336],
#        [-2.79290307,  2.79641063],
#        [-1.46679593,  2.28585348],
#        [-2.80037642,  1.30082566]])
# array([1, 1, 2, 2])

# %% [markdown]
# ### Decision Boundaries

# %%
def plot_data(X):
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize = 2)
def plot_centroids(centroids, weights = None, circle_color = 'w', cross_color = 'k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1], 
                marker = 'o', s = 30, linewidths = 8,
                color = circle_color, zorder = 10, alpha = 0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1], 
                marker = 'x', s = 50, linewidths = 50,
                color = cross_color, zorder = 11, alpha = 1)
def plot_decision_boundaries(clusterer, X, resolution = 1000, \
                             show_centroids = True, show_xlabels = True, \
                             show_ylabels = True):
    mins = X.min(axis = 0) - 0.1
    maxs = X.max(axis = 0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(Z, extent = (mins[0], maxs[0], mins[1], maxs[1]), cmap = "Pastel2")
    plt.contour(Z, extent = (mins[0], maxs[0], mins[1], maxs[1]), linewidths = 1, \
                             colors = 'k')
    plot_data(X)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)
    if show_xlabels:
        plt.xlabel("$x_1$", fontsize = 14)
    else:
        plt.tick_params(labelbottom = False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize = 14, rotation = 0)
    else:
        plt.tick_params(labelleft = False)

# %%
plt.figure(figsize = (8, 4))
plot_decision_boundaries(kmeans, X)
save_fig("voronoi_plot")
plt.show()

# %% [markdown]
# ### Hard Clustering vs. Soft Clustering

# %%
# The transform() method measures the distance of each instance to all centroids
display(kmeans.transform(X_new))
# Verification, same as Euclidian distance
E_distance = np.linalg.norm(np.tile(X_new, (1, k)).reshape(-1, k, 2) - \
                            kmeans.cluster_centers_, axis = 2)
display(E_distance)

# Soft clustering could be used for dimensionality reduction
# Out:
# array([[2.81093633, 0.32995317, 2.9042344 , 1.49439034, 2.88633901],
#        [5.80730058, 2.80290755, 5.84739223, 4.4759332 , 5.84236351],
#        [1.21475352, 3.29399768, 0.29040966, 1.69136631, 1.71086031],
#        [0.72581411, 3.21806371, 0.36159148, 1.54808703, 1.21567622]])
# array([[2.81093633, 0.32995317, 2.9042344 , 1.49439034, 2.88633901],
#        [5.80730058, 2.80290755, 5.84739223, 4.4759332 , 5.84236351],
#        [1.21475352, 3.29399768, 0.29040966, 1.69136631, 1.71086031],
#        [0.72581411, 3.21806371, 0.36159148, 1.54808703, 1.21567622]])

# %% [markdown]
# ### K-Means Algorithm
# * Initialization: Choose $k$ distinct instances randomly and place centroids at their locations
# * Training:
#     * Assign each instance to the closest centroid
#     * Update the centroids to the mean of the instances assigned to them
# * Sklearn: To use vanilla K-Means, set `init = "random`, `n_init = 1`, and `algorithm = "full"`.

# %%
kmeans_iter1 = KMeans(n_clusters = 5, init = "random", n_init = 1, \
                      algorithm = "full", max_iter = 1, random_state = 1)
kmeans_iter2 = KMeans(n_clusters = 5, init = "random", n_init = 1, \
                      algorithm = "full", max_iter = 2, random_state = 1)
kmeans_iter3 = KMeans(n_clusters = 5, init = "random", n_init = 1, \
                      algorithm = "full", max_iter = 3, random_state = 1)
kmeans_iter1.fit(X); kmeans_iter2.fit(X); kmeans_iter3.fit(X);
plt.figure(figsize=(10, 8))

plt.subplot(321)
plot_data(X)
plot_centroids(kmeans_iter1.cluster_centers_, circle_color='r', cross_color='w')
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.tick_params(labelbottom=False)
plt.title("Update the centroids (initially randomly)", fontsize=14)

plt.subplot(322)
plot_decision_boundaries(kmeans_iter1, X, show_xlabels=False, show_ylabels=False)
plt.title("Label the instances", fontsize=14)

plt.subplot(323)
plot_decision_boundaries(kmeans_iter1, X, show_centroids=False, show_xlabels=False)
plot_centroids(kmeans_iter2.cluster_centers_)

plt.subplot(324)
plot_decision_boundaries(kmeans_iter2, X, show_xlabels=False, show_ylabels=False)

plt.subplot(325)
plot_decision_boundaries(kmeans_iter2, X, show_centroids=False)
plot_centroids(kmeans_iter3.cluster_centers_)

plt.subplot(326)
plot_decision_boundaries(kmeans_iter3, X, show_ylabels=False)

save_fig("kmeans_algorithm_plot")
plt.show()
# Out:
# Saving figure kmeans_algorithm_plot

# %% [markdown]
# ### K-Means Variability
# * If using randomly initialization, the algo may converge to different solutions

# %%
def plot_clusterer_comparison(clusterer1, clusterer2, X, title1 = None, \
                              title2 = None):
    clusterer1.fit(X)
    clusterer2.fit(X)
    plt.figure(figsize = (10, 3.2))
    plt.subplot(121)
    plot_decision_boundaries(clusterer1, X)
    if title1:
        plt.title(title1, fontsize = 14)
    plt.subplot(122)
    plot_decision_boundaries(clusterer2, X, show_ylabels = False)
    if title2:
        plt.title(title2, fontsize = 14)
kmeans_rnd_init1 = KMeans(n_clusters = 5, init = "random", n_init = 1, 
                          algorithm = "full", random_state = 11)
kmeans_rnd_init2 = KMeans(n_clusters = 5, init = "random", n_init = 1, 
                          algorithm = "full", random_state = 19)
plot_clusterer_comparison(kmeans_rnd_init1, kmeans_rnd_init2, X, 
                          "Solution1", "Solution2 (different random_state)")
save_fig("KMeans_variability_plot")
plt.show()
# Out:
# Saving figure KMeans_variability_plot

# %% [markdown]
# ### Inertia
# * Sum of the squared distances between each training instance to its closest centroid.

# %%
display(kmeans.inertia_)
X_dist = kmeans.transform(X)
display(np.sum(X_dist[np.arange(len(X_dist)), kmeans.labels_] ** 2))
# The score() method return the negative inertia, the greater the better
display(kmeans.score(X))
# Out:
# 211.5985372581684
# 211.59853725816856
# -211.59853725816856

# %% [markdown]
# ### Multiple Initializations

# %%
# Run KMeans multiple times and select the one with minimum inertia
display(kmeans_rnd_init1.inertia_, kmeans_rnd_init2.inertia_)
# The n_init controlls how many initializations KMeans will try
kmeans_rnd_10_inits = KMeans(n_clusters = 5, init = "random", n_init = 10, \
                             algorithm = "full", random_state = 13)
display(kmeans_rnd_10_inits.fit(X))
plt.figure(figsize = (8, 4))
plot_decision_boundaries(kmeans_rnd_10_inits, X)
plt.show()
# Out:
# 223.29108572819035
# 237.46249169442845
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=300, n_clusters=5,
#        n_init=10, n_jobs=None, precompute_distances='auto', random_state=13,
#        tol=0.0001, verbose=0)

# %% [markdown]
# ### K-Means++
# * Take one centroid $c_1$, chosen uniformly at random from the dataset.
# * Take a new center $c_i$, choosing an instance $\mathbf{x}_i$ with probability: $D(\mathbf{x}_i)^2$ / $\sum\limits_{j=1}^{m}{D(\mathbf{x}_j)}^2$ where $D(\mathbf{x}_i)$ is the distance between the instance $\mathbf{x}_i$ and the closest centroid that was chosen. This makes sure that instances further away from chosen centroids are more likely to be chosen as new centroids.
# * Repeat last step till k centroids are chosen.

# %%
# K-Means++ is the default
display(KMeans())
good_init = np.array([[-3, 3], [-3, 2], [-3, 1], [-1, 2], [0, 2]])
kmeans = KMeans(n_clusters = 5, init = good_init, n_init = 1, random_state = 42)
kmeans.fit(X)
display(kmeans.inertia_)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)
# 211.5985372581684

# %% [markdown]
# ### Accelerated K-Means
# * Take advantage of the triangle inequality, many calculations can be avoid.

# %%
# The algorithm = "elkan" only support dense data, "full" is for sparse data.
# %timeit -n 50 KMeans(algorithm = "elkan").fit(X)
# %timeit -n 50 KMeans(algorithm = "full").fit(X)
# Out:
# 79.1 ms ± 4.96 ms per loop (mean ± std. dev. of 7 runs, 50 loops each)
# 89.6 ms ± 1.54 ms per loop (mean ± std. dev. of 7 runs, 50 loops each)

# %% [markdown]
# ### Mini-Batch K-Means

# %%
from sklearn.cluster import MiniBatchKMeans
minibatch_kmeans = MiniBatchKMeans(n_clusters = 5, random_state = 42)
display(minibatch_kmeans.fit(X))
display(minibatch_kmeans.inertia_)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=5, n_init=3, random_state=42,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)
# 211.93186531476775

# %%
# For large dataset
from six.moves import urllib
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
mnist = fetch_openml('mnist_784', version = 1)
mnist.target = mnist.target.astype(np.int64)
X_train, X_test, y_train, y_tesy = train_test_split(
    mnist["data"], mnist["target"], random_state = 42)
filename = "my_mnist.data"
if not os.path.exists(filename):
    X_mm = np.memmap(filename, dtype = 'float32', mode = 'write', \
                     shape = X_train.shape)
    X_mm[:] = X_train
else:
    X_mm = np.memmap(filename, dtype = 'float32', mode = 'readonly', \
                     shape = X_train.shape)
minibatch_kmeans = MiniBatchKMeans(n_clusters = 10, batch_size = 10, random_state = 42)
display(minibatch_kmeans.fit(X_mm))
# Out:
# MiniBatchKMeans(batch_size=10, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=10, n_init=3, random_state=42,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
# If the data is to large for memmap
def load_next_batch(batch_size):
    return X[np.random.choice(len(X), batch_size, replace = False)]
np.random.seed(42)
k, n_init, n_iterations = 5, 10, 100
batch_size, init_size = 100, 500
evaluate_on_last_n_iters = 10
best_kmeans = None
for init in range(n_init):
    minibatch_kmeans = MiniBatchKMeans(n_clusters = k, init_size = init_size)
    X_init = load_next_batch(init_size)
    minibatch_kmeans.partial_fit(X_init)
    minibatch_kmeans.sum_inertia_ = 0
    for iteration in range(n_iterations):
        X_batch = load_next_batch(batch_size)
        minibatch_kmeans.partial_fit(X_batch)
        if iteration >= n_iterations - evaluate_on_last_n_iters:
            minibatch_kmeans.sum_inertia_ += minibatch_kmeans.inertia_
    if (best_kmeans is None or 
        minibatch_kmeans.sum_inertia_ < best_kmeans.sum_inertia_):
        best_kmeans = minibatch_kmeans
display(best_kmeans.score(X))
# %timeit KMeans(n_clusters = 5).fit(X)
# %timeit MiniBatchKMeans(n_clusters = 5).fit(X)
# Out:
# -211.70999744411483
# 39.7 ms ± 1.04 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 21.6 ms ± 1.98 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from timeit import timeit
times = np.empty((100, 2))
inertias = np.empty((100, 2))
for k in range(1, 101):
    kmeans_ = KMeans(n_clusters = k, random_state = 42)
    minibatch_kmeans = MiniBatchKMeans(n_clusters = k, random_state = 42)
    print("\r{}/{}".format(k, 100), end="")
    times[k-1, 0] = timeit("kmeans_.fit(X)", number=10, globals=globals())
    times[k-1, 1]  = timeit("minibatch_kmeans.fit(X)", number=10, globals=globals())
    inertias[k-1, 0] = kmeans_.inertia_
    inertias[k-1, 1] = minibatch_kmeans.inertia_
plt.figure(figsize=(10,4))

plt.subplot(121)
plt.plot(range(1, 101), inertias[:, 0], "r--", label="K-Means")
plt.plot(range(1, 101), inertias[:, 1], "b.-", label="Mini-batch K-Means")
plt.xlabel("$k$", fontsize=16)
plt.title("Inertia", fontsize=14)
plt.legend(fontsize=14)
plt.axis([1, 100, 0, 100])

plt.subplot(122)
plt.plot(range(1, 101), times[:, 0], "r--", label="K-Means")
plt.plot(range(1, 101), times[:, 1], "b.-", label="Mini-batch K-Means")
plt.xlabel("$k$", fontsize=16)
plt.title("Training time (seconds)", fontsize=14)
plt.axis([1, 100, 0, 6])

save_fig("minibatch_kmeans_vs_kmeans")
plt.show()
# Out:
# 100/100Saving figure minibatch_kmeans_vs_kmeans

# %% [markdown]
# ### Finding the optimal number of k

# %%
kmeans_per_k = [KMeans(n_clusters = k, random_state = 42).fit(X)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]
plt.figure(figsize=(8, 3.5))
plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.annotate('Elbow',
             xy=(4, inertias[3]),
             xytext=(0.55, 0.55),
             textcoords='figure fraction',
             fontsize=16,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.axis([1, 8.5, 0, 1300])
save_fig("inertia_vs_k_plot")
plt.show()
# Out:
# Saving figure inertia_vs_k_plot

# %% [markdown]
# Finding the Elbow is not an effecient way.
#
# Another way is the silhouette score_, which is the mean_silhouette coef. over
# all instances. Sil-coef is between -1 and +1, equals to $(b-a)/\max(a,b)$.
#
# * $a$ means the mean distance to the other instances in the same cluster
# * $b$ is the mean distance to the instances in the closest cluster

# %%
from sklearn.metrics import silhouette_score
display(silhouette_score(X, kmeans.labels_))
silhouette_scores = [silhouette_score(X, model.labels_)
                     for model in kmeans_per_k[1 :]]
plt.figure(figsize=(8, 3))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.axis([1.8, 8.5, 0.55, 0.7])
save_fig("silhouette_score_vs_k_plot")
plt.show()
# Out:
# 0.655517642572828
# Saving figure silhouette_score_vs_k_plot

# %%
# The _silhouette diagram_ plots every instance's silhouette coef. sorted by
# clusters and value
from sklearn.metrics import silhouette_samples
from matplotlib.ticker import FixedLocator, FixedFormatter
plt.figure(figsize = (11, 9))
for k in range(3, 7):
    plt.subplot(2, 2, k - 2)
    y_pred = kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(X, y_pred)
    padding = len(X) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()
        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs, \
                         facecolor = color, edgecolor = color, alpha = 0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding
    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (3, 5):
        plt.ylabel("Cluster")
    if k in (5, 6):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1.])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom = False)
    # Use plt.axvline
    plt.axvline(x = silhouette_scores[k - 2], color = "red", linestyle = "--")
    plt.title("$k = {}$".format(k), fontsize = 16)
save_fig("Silhouette_analysis_plot")
plt.show()

# The red dashed line is the overall silhouette score of each KMean
# If a bar falls left to the dashed line, that cluster is poor because it's too
# close to other clusters. That's in k = 3 and 6.
# Out:
# Saving figure Silhouette_analysis_plot

# %% [markdown]
# ### Limits of K-Means

# %%
X1, y1 = make_blobs(n_samples = 1000, centers = ((4, -4), (0, 0)), random_state = 42)
X1 = X1.dot(np.array([[0.347, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples = 250, centers = 1, random_state = 42)
X2 = X2 + [6, -8]
X, y = np.r_[X1, X2], np.r_[y1, y2]
plot_clusters(X)

# %%
kmeans_good = KMeans(n_clusters = 3, \
                     init = np.array([[-1.5, 2.5], [0.5, 0], [4, 0]]), \
                     n_init = 1, random_state = 42)
kmeans_bad = KMeans(n_clusters = 3, random_state = 42)
kmeans_good.fit(X); kmeans_bad.fit(X);
plt.figure(figsize=(10, 3.2))

plt.subplot(121)
plot_decision_boundaries(kmeans_good, X)
plt.title("Inertia = {:.1f}".format(kmeans_good.inertia_), fontsize=14)

plt.subplot(122)
plot_decision_boundaries(kmeans_bad, X, show_ylabels=False)
plt.title("Inertia = {:.1f}".format(kmeans_bad.inertia_), fontsize=14)

save_fig("bad_kmeans_plot")
plt.show()
# LOL, KMeans is updated
# It's important to scale the input features to be more spherical before K-Means
# Out:
# Saving figure bad_kmeans_plot

# %% [markdown]
# ### Using clustering for image segmentation
# * Semantic segmentation, segment all pixels in the same object type
# * Instance segmentation, segment all pixels in the same individual object
# * The example below is color segmentation

# %%
from matplotlib.image import imread 
# Or imageio.imread(), the color scale would be 0 to 255
image = imread(os.path.join("images", "unsupervised_learning", "ladybug.png"))
display(image.shape)
plt.imshow(image)
# Why?
X = image.reshape(-1, 3)
display(image.shape)
#plt.imshow(image)
# kmeans = KMeans(n_clusters = 8, random_state = 42).fit(X)
# segmented_img = kmeans.cluster_centers_[kmeans.labels_]
# segmented_img = segmented_img.reshape(image.shape)
segmented_imgs = []
n_colors = (10, 8, 6, 4, 2)
for n_clusters in n_colors:
    # Assign each centroid's color to replace all instances in its cluster
    # The color of each centroid is generated
    kmeans = KMeans(n_clusters = n_clusters, random_state = 42).fit(X)
    segmented_img = kmeans.cluster_centers_[kmeans.labels_]
    segmented_imgs.append(segmented_img.reshape(image.shape))
plt.figure(figsize=(10,5))
plt.subplots_adjust(wspace=0.05, hspace=0.1)

plt.subplot(231)
plt.imshow(image)
plt.title("Original image")
plt.axis('off')

for idx, n_clusters in enumerate(n_colors):
    plt.subplot(232 + idx)
    plt.imshow(segmented_imgs[idx])
    plt.title("{} colors".format(n_clusters))
    plt.axis('off')

save_fig('image_segmentation_diagram', tight_layout=False)
plt.show()
# K-Means prefers clusters of similar sizes, the ladybug's too small.
# Out:
# (533, 800, 3)
# (533, 800, 3)
# Saving figure image_segmentation_diagram

# %% [markdown]
# ### Using Clustering for Preprocessing
# * K-Means can be used for dimentionality reduction

# %%
# Create baseline accuracy
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X_digits, y_digits = load_digits(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X_digits, y_digits, \
                                                    random_state = 42)
log_reg = LogisticRegression(multi_class = "ovr", solver = "lbfgs", \
                             max_iter = 5000, random_state = 42)
display(log_reg.fit(X_train, y_train))
display(log_reg.score(X_train, y_train))
display(log_reg.score(X_test, y_test))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=5000,
#                    multi_class='ovr', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# 0.9970304380103935
# 0.9688888888888889

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ("kmeans", KMeans(n_clusters = 50, random_state = 42)),
    ("log_reg", LogisticRegression(multi_class = "ovr", solver = "lbfgs", \
                                   max_iter = 5000, random_state = 42))
])
pipeline.fit(X_train, y_train)
display(pipeline.score(X_test, y_test))
# Out:
# 0.9777777777777777

# %%
# Select optimal k
from sklearn.model_selection import GridSearchCV
param_grid = dict(kmeans__n_clusters = range(2, 100))
grid_clf = GridSearchCV(pipeline, param_grid, cv = 3, verbose = 0)
grid_clf.fit(X_train, y_train)
display(grid_clf.best_params_)
display(grid_clf.score(X_test, y_test))
# Out:
# {'kmeans__n_clusters': 77}
# 0.9822222222222222

# %% [markdown]
# ### Clustering for Semi-supervised Learning

# %%
n_labeled = 50
log_reg = LogisticRegression(multi_class = "ovr", solver = "lbfgs", \
                             random_state = 42)
log_reg.fit(X_train[: n_labeled], y_train[: n_labeled])
display(log_reg.score(X_test, y_test))
k = 50
kmeans = KMeans(n_clusters = k, random_state = 42)
X_digits_dist = kmeans.fit_transform(X_train)
representative_digit_idx = np.argmin(X_digits_dist, axis = 0)
X_representative_digits = X_train[representative_digit_idx]
plt.figure(figsize = (8, 2))
for index, X_representative_digit in enumerate(X_representative_digits):
    plt.subplot(k // 10, 10, index + 1)
    plt.imshow(X_representative_digit.reshape(8, 8), cmap = "binary", \
               interpolation = "bilinear")
    plt.axis("off")
save_fig("representative_images_diagram", tight_layout = False)
plt.show()
# Out:
# 0.8333333333333334
# Saving figure representative_images_diagram

# %%
y_representative_digits = np.array([
    4, 8, 0, 6, 8, 3, 7, 7, 9, 2,
    5, 5, 8, 5, 2, 1, 2, 9, 6, 1,
    1, 6, 9, 0, 8, 3, 0, 7, 4, 1,
    6, 5, 2, 4, 1, 8, 6, 3, 9, 2,
    4, 2, 9, 4, 7, 6, 2, 3, 1, 1])

log_reg = LogisticRegression(multi_class = "ovr", solver = "lbfgs", \
                             max_iter = 5000, random_state = 42)
log_reg.fit(X_representative_digits, y_representative_digits)
display(log_reg.score(X_test, y_test))
# Out:
# 0.9222222222222223

# %%
# Label propagation
y_train_propagated = np.empty(len(X_train), dtype = np.int32)
for i in range(k):
    y_train_propagated[kmeans.labels_ == i] = y_representative_digits[i]
log_reg = LogisticRegression(multi_class = "ovr", solver = "lbfgs", \
                             max_iter = 5000, random_state = 42)
log_reg.fit(X_train, y_train_propagated)
display(log_reg.score(X_test, y_test))
# Out:
# 0.9333333333333333

# %%
# Now use only the intances close to their centroids
percentile_closest = 20
X_cluster_dist = X_digits_dist[np.arange(len(X_train)), kmeans.labels_]
for i in range(k):
    in_cluster = (kmeans.labels_ == i)
    cluster_dist = X_cluster_dist[in_cluster]
    cutoff_distance = np.percentile(cluster_dist, percentile_closest)
    above_cutoff = (X_cluster_dist > cutoff_distance)
    X_cluster_dist[in_cluster & above_cutoff] = -1
partially_propagated = (X_cluster_dist != -1)
X_train_partially_propagated = X_train[partially_propagated]
y_train_partially_propagated = y_train_propagated[partially_propagated]
log_reg = LogisticRegression(multi_class = "ovr", solver = "lbfgs", \
                             max_iter = 5000, random_state = 42)
log_reg.fit(X_train_partially_propagated, y_train_partially_propagated)
display(log_reg.score(X_test, y_test))
display(np.mean(y_train_partially_propagated == y_train[partially_propagated]))
# Out:
# 0.94
# 0.9896907216494846

# %% [markdown]
# ### Active Learning
# * Model trained with labeled data and predict unlabeled data
# * Label the instances with lowest probability by experts
# * Iterate above

# %% [markdown]
# ## DBSCAN
# * Counts the $\epsilon$-neighborhood, how many instances located within a small distance $\epsilon$
# * Core instance are identified by counting $min_samples$ in its $\epsilon$-neighborhood
# * All instances in the neighborhood of a core instance belong to the same cluster, may include other core instances
# * Instances who's not a core nor in any cores' $\epsilon$-neighborhood is considered as an anomaly
#
# This algo works well if al clusters are dense enough.

# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
X, y = make_moons(n_samples = 1000, noise = 0.05, random_state = 42)
dbscan = DBSCAN(eps = 0.05, min_samples = 5)
dbscan.fit(X)
display(dbscan.labels_[: 10])
display(len(dbscan.core_sample_indices_))
display(dbscan.core_sample_indices_[: 10], dbscan.components_[:3])
display(np.unique(dbscan.labels_))
dbscan2 = DBSCAN(eps = 0.2)
display(dbscan2.fit(X))

# DBSCAN cannot use predict() method, so it cannot predict which cluster a
# new instance belongs to.
# But it has fit_predict(), which returns instances' labels
# Out:
# array([ 0,  2, -1, -1,  1,  0,  0,  0,  2,  5], dtype=int64)
# 808
# array([ 0,  4,  5,  6,  7,  8, 10, 11, 12, 13], dtype=int64)
# array([[-0.02137124,  0.40618608],
#        [-0.84192557,  0.53058695],
#        [ 0.58930337, -0.32137599]])
# array([-1,  0,  1,  2,  3,  4,  5,  6], dtype=int64)
# DBSCAN(algorithm='auto', eps=0.2, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
def plot_dbscan(dbscan, X, size, show_xlabels = True, show_ylabels = True):
    core_mask = np.zeros_like(dbscan.labels_, dtype = bool)
    core_mask[dbscan.core_sample_indices_] = True
    anomalies_mask = dbscan.labels_ == -1
    non_core_mask = ~(core_mask | anomalies_mask)
    cores = dbscan.components_
    anomalies = X[anomalies_mask]
    non_cores = X[non_core_mask]
    plt.scatter(cores[:, 0], cores[:, 1],
                c = dbscan.labels_[core_mask], marker = "o", s = size, cmap = "Paired")
    plt.scatter(cores[:, 0], cores[:, 1], marker = "*", s = 20, \
                c = dbscan.labels_[core_mask])
    plt.scatter(anomalies[:, 0], anomalies[:, 1],
                c = "r", marker = "x", s = 100)
    plt.scatter(non_cores[:, 0], non_cores[:, 1], c = dbscan.labels_[non_core_mask], \
                marker = ".")
    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title("eps={:.2f}, min_samples={}".format(dbscan.eps, dbscan.min_samples), fontsize=14)
plt.figure(figsize=(9, 3.2))

plt.subplot(121)
plot_dbscan(dbscan, X, size=100)

plt.subplot(122)
plot_dbscan(dbscan2, X, size=600, show_ylabels=False)

save_fig("dbscan_plot")
plt.show()
dbscan = dbscan2
# Out:
# Saving figure dbscan_plot

# %%
# To plot decision boundaries, use KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 50)
display(knn.fit(dbscan.components_, dbscan.labels_[dbscan.core_sample_indices_]))
X_new = np.array([[-0.5, 0], [0, 0.5], [1, -0.1], [2, 1]])
display(knn.predict(X_new))
display(knn.predict_proba(X_new))
plt.figure(figsize=(6, 3))
plot_decision_boundaries(knn, X, show_centroids=False)
plt.scatter(X_new[:, 0], X_new[:, 1], c="b", marker="+", s=200, zorder=10)
save_fig("cluster_classification_plot")
plt.show()

# This is not quiet right, the results given by knn and DBSCAN are different
y_dist, y_pred_idx = knn.kneighbors(X_new, n_neighbors = 1)
y_pred = dbscan.labels_[dbscan.core_sample_indices_][y_pred_idx]
y_pred[y_dist > 0.2] = -1
y_pred.ravel()
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=50, p=2,
#                      weights='uniform')
# array([1, 0, 1, 0], dtype=int64)
# array([[0.18, 0.82],
#        [1.  , 0.  ],
#        [0.12, 0.88],
#        [1.  , 0.  ]])
# Saving figure cluster_classification_plot
# array([-1,  0,  1, -1], dtype=int64)

# %% [markdown]
# ## Other Clustering Algorithms
# ### Spectral Clustering
# * First reduce dimentionality with similarity matrix then perform clustering

# %%
from sklearn.cluster import SpectralClustering
sc1 = SpectralClustering(n_clusters = 2, gamma = 100, random_state = 42)
display(sc1.fit(X))
sc2 = SpectralClustering(n_clusters = 2, gamma = 1, random_state = 42)
display(sc2.fit(X))
display(np.percentile(sc1.affinity_matrix_, 95))

def plot_spectral_clustering(sc, X, size, alpha, show_xlabels=True, show_ylabels=True):
    plt.scatter(X[:, 0], X[:, 1], marker='o', s=size, c='gray', cmap="Paired", alpha=alpha)
    plt.scatter(X[:, 0], X[:, 1], marker='o', s=30, c='w')
    plt.scatter(X[:, 0], X[:, 1], marker='.', s=10, c=sc.labels_, cmap="Paired")
    
    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title("RBF gamma={}".format(sc.gamma), fontsize=14)
plt.figure(figsize=(9, 3.2))

plt.subplot(121)
plot_spectral_clustering(sc1, X, size=500, alpha=0.1)

plt.subplot(122)
plot_spectral_clustering(sc2, X, size=4000, alpha=0.01, show_ylabels=False)

plt.show()
# Out:
# SpectralClustering(affinity='rbf', assign_labels='kmeans', coef0=1, degree=3,
#                    eigen_solver=None, eigen_tol=0.0, gamma=100,
#                    kernel_params=None, n_clusters=2, n_init=10, n_jobs=None,
#                    n_neighbors=10, random_state=42)
# SpectralClustering(affinity='rbf', assign_labels='kmeans', coef0=1, degree=3,
#                    eigen_solver=None, eigen_tol=0.0, gamma=1,
#                    kernel_params=None, n_clusters=2, n_init=10, n_jobs=None,
#                    n_neighbors=10, random_state=42)
# 0.04251990648936265

# %% [markdown]
# ### Agglomerative Clustering
# * A hierarchy of clusters is build from the bottom.
# * Can be provided with a connectivity matrix

# %%
from sklearn.cluster import AgglomerativeClustering
X = np.array([0, 2, 5, 8.5]).reshape(-1, 1)
agg = AgglomerativeClustering(linkage = "complete").fit(X)
def learned_parameters(estimator):
    return [attrib for attrib in dir(estimator)
            if attrib.endswith("_") and not attrib.startswith("_")]
display(learned_parameters(agg))
display(agg.children_)
# Out:
# ['children_',
#  'labels_',
#  'n_clusters_',
#  'n_components_',
#  'n_connected_components_',
#  'n_leaves_']
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %% [markdown]
# ## Gaussian Mixture Model (GMM)
# * It's based on the Expectation Maximization (EM) algo.

# %%
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture

X1, y1 = make_blobs(n_samples = 1000, centers = ((4, -4), (0, 0)), random_state = 42)
X1 = X1.dot(np.array([[0.374, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples = 250, centers = 1, random_state = 42)
X2 = X2 + [6, -8]
X = np.r_[X1, X2]
y = np.r_[y1, y2]

# Like K-Means, EM is sensitive to initializations, and the default of n_init = 10!!!
# Set larger n_init.
gm = GaussianMixture(n_components = 3, n_init = 10, random_state = 42)
display("Fitting: ", gm.fit(X))
display("weights:", gm.weights_) # Very close to 250 : 500 : 500, decides the occurence
display("means:", gm.means_) # Decides the location of centroids
display("covariances:", gm.covariances_) # Decides the shape and orientation of the clusters
display("converged:", gm.converged_)
display("n_iterations:", gm.n_iter_)
display("Predictions:", gm.predict(X))
display("Predict Probabilities:", gm.predict_proba(X))

# The gm function is also a generative model
X_new, y_new = gm.sample(6)
display("X_new:", X_new)
display("y_new:", y_new)
# Estimate the log of PDF using score_samples() method, equals to the density
display("log(PDF):", gm.score_samples(X_new))
# Out:
# 'Fitting: '
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=3, n_init=10,
#                 precisions_init=None, random_state=42, reg_covar=1e-06,
#                 tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#                 weights_init=None)
# 'weights:'
# array([0.20965228, 0.4000662 , 0.39028152])
# 'means:'
# array([[ 3.39909717,  1.05933727],
#        [-1.40763984,  1.42710194],
#        [ 0.05135313,  0.07524095]])
# 'covariances:'
# array([[[ 1.14807234, -0.03270354],
#         [-0.03270354,  0.95496237]],
#
#        [[ 0.63478101,  0.72969804],
#         [ 0.72969804,  1.1609872 ]],
#
#        [[ 0.68809572,  0.79608475],
#         [ 0.79608475,  1.21234145]]])
# 'converged:'
# True
# 'n_iterations:'
# 4
# 'Predictions:'
# array([2, 2, 1, ..., 0, 0, 0], dtype=int64)
# 'Predict Probabilities:'
# array([[2.32389467e-02, 6.77397850e-07, 9.76760376e-01],
# ...

# %%
from matplotlib.colors import LogNorm

resolution = 100
grid = np.arange(-10, 10, 1 / resolution)
xx, yy = np.meshgrid(grid, grid)
X_full = np.vstack([xx.ravel(), yy.ravel()]).T
pdf = np.exp(gm.score_samples(X_full))
pdf_probas = pdf * (1 / resolution) ** 2
display("Sum(pdf_probas):", pdf_probas.sum())

def plot_gaussian_mixture(clusterer, X, resolution = 1000, show_ylabels = True):
    mins = X.min(axis = 0) - 0.1
    maxs = X.max(axis = 0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    # Probability density contours
    plt.contourf(xx, yy, Z, norm = LogNorm(vmin = 1.0, vmax = 30.0), 
                 levels = np.logspace(0, 2, 12))
    plt.contour(xx, yy, Z, norm = LogNorm(vmin = 1.0, vmax = 30.0),
                 levels = np.logspace(0, 2, 12), linewidths = 1, colors = "k")
    
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Decision boundaries
    plt.contour(xx, yy, Z, linewidths = 2, colors = "r", linestyles = "dashed")
    plt.plot(X[:, 0], X[:, 1], "k.", markersize = 2)
    plot_centroids(clusterer.means_, clusterer.weights_)
    plt.xlabel("$x_1$", fontsize = 14)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize = 14, rotation = 0)
    else:
        plt.tick_params(labelleft = False)
plt.figure(figsize = (8, 4))
plot_gaussian_mixture(gm, X)
save_fig("gaussian_mixtures_plot")
plt.show()
# Out:
# 'Sum(pdf_probas):'
# 0.9999999999217849
# Saving figure gaussian_mixtures_plot

# %%
# With some prior knowledge, we can simplify the task by regularizing the shapes
# and orientations the mixtures can have, using the covariance_type handle.

# By default, it's "full", unconstrained and dosen't scale well with feature 
# dimentionality
gm_full = GaussianMixture(n_components = 3, n_init = 10, covariance_type = "full", \
                          random_state = 42).fit(X)

# "spherical", spherical clusters with different diameters
gm_spherical = GaussianMixture(n_components = 3, n_init = 10, \
                               covariance_type = "spherical", \
                               random_state = 42).fit(X)

# "diag", ellipsoidal and diagonal clusters, means the covariance matrices are 
# diagonal. "spherical" and "diag" scales better with feature dimentionality
gm_diag = GaussianMixture(n_components = 3, n_init = 10, covariance_type = "diag", \
                          random_state = 42).fit(X)

# "tied", all clusters have the same shape, shares the same covariance matrix
gm_tied = GaussianMixture(n_components = 3, n_init = 10, covariance_type = "tied", \
                          random_state = 42).fit(X)

def compare_gaussian_mixtures(gm1, gm2, X):
    plt.figure(figsize = (9, 4))
    plt.subplot(121)
    plot_gaussian_mixture(gm1, X)
    plt.title("covariance_type = '{}'".format(gm1.covariance_type), fontsize = 14)
    plt.subplot(122)
    plot_gaussian_mixture(gm2, X, show_ylabels = False)
    plt.title("covariance_type = '{}'".format(gm2.covariance_type), fontsize = 14)
compare_gaussian_mixtures(gm_tied, gm_spherical, X)
save_fig("covariance_type_tied_spherical_plot")
plt.show()
compare_gaussian_mixtures(gm_full, gm_diag, X)
save_fig("covariance_type_fill_diag_plot")
plt.show()
# Out:
# (1000000,)
# (1000, 1000)
# (1000000,)
# (1000, 1000)
# Saving figure covariance_type_tied_spherical_plot
# (1000000,)
# (1000, 1000)
# (1000000,)
# (1000, 1000)
# Saving figure covariance_type_fill_diag_plot

# %% [markdown]
# ## Anomaly Detection using Gaussian Mixtures

# %%
# Take the threshold of 4%
densities = gm.score_samples(X)
density_threshold = np.percentile(densities, 4)
anomalies = X[densities < density_threshold]
plt.figure(figsize = (8, 4))
plot_gaussian_mixture(gm, X)
plt.scatter(anomalies[:, 0], anomalies[:, 1], color = "r", marker = "*")
plt.ylim(top = 5.1)
save_fig("mixture_anomaly_detection_plot")
plt.show()

X_cleaned = X[densities >= density_threshold]
gm_cleaned = GaussianMixture(n_components = 3, n_init = 10, random_state = 42).fit(X_cleaned)
plt.figure(figsize = (8, 4))
plot_gaussian_mixture(gm_cleaned, X_cleaned)
plt.ylim(top = 4.1)
save_fig("mixture_anomaly_cleaned_plot")
plt.show()

# Another approach is to use the robust covariance estimation methods like 
# EllipticEnvelope class. The contamination handle specify the outliers fraction
from sklearn.covariance import EllipticEnvelope
EE = EllipticEnvelope(contamination = 0.04, random_state = 42).fit(X)
# Out:
# (1000000,)
# (1000, 1000)
# Saving figure mixture_anomaly_detection_plot
# (1000000,)
# (1000, 1000)
# Saving figure mixture_anomaly_cleaned_plot

# %% [markdown]
# ## Model Selection
# * How to decide n_components?
#     We can't use inertia or the silhouette score because they both assume the clusters are spherical.
# * Use models that minimizes a theoretical information criterion
# * Akaike Informaton Criterion (AIC)
#
#     ${AIC} = 2p - 2\log(\hat L)$
# * Bayesian Information Criterion (BIC)
#
#     ${BIC} = \log(m)p - 2\log({\hat L})$
#
#     * $m$, the number of instances
#     * $p$, the number of parameters learned
#     * ${\hat L}$, the maximum likelihood of X

# %%
display("AIC:", gm.aic(X), "BIC:", gm.bic(X))
# To manually compute AIC and BIC
n_clusters, n_dims = 3, 2
n_params_for_weights = n_clusters - 1
n_params_for_means = n_clusters * n_dims
n_params_for_covariance = n_clusters * n_dims * (n_dims + 1) // 2
n_params = n_params_for_weights + n_params_for_means + n_params_for_covariance
max_log_likelihood = gm.score(X) * len(X) # log(L^)
aic = 2 * n_params - 2 * max_log_likelihood
bic = np.log(len(X)) * n_params - 2 * max_log_likelihood
display("AIC_manual:", aic, "BIC_manual:", bic, "n_parameters", n_params)
# Out:
# 'AIC:'
# 8102.518178214792
# 'BIC:'
# 8189.74345832983
# 'AIC_manual:'
# 8102.518178214792
# 'BIC_manual:'
# 8189.74345832983
# 'n_parameters'
# 17

# %%
gms_per_k = [GaussianMixture(n_components = k, n_init = 10, random_state = 42).fit(X) \
             for k in range(1, 11)]
aics = [model.aic(X) for model in gms_per_k]
bics = [model.bic(X) for model in gms_per_k]
plt.figure(figsize = (8, 3))
plt.plot(range(1, 11), aics, "go--", label = "AIC")
plt.plot(range(1, 11), bics, "bo-", label = "BIC")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Information Criterion", fontsize=14)
plt.axis([1, 9.5, np.min(aics) - 50, np.max(aics) + 50])
plt.annotate('Minimum',
             xy=(3, bics[2]),
             xytext=(0.35, 0.6),
             textcoords='figure fraction',
             fontsize=14,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.legend()
save_fig("aic_bic_vs_k_plot")
plt.show()
# BIC punishes large parameterization harder.
# Out:
# Saving figure aic_bic_vs_k_plot

# %%
# Search for best covariance_type
min_bic = np.infty
for k in range(1, 11):
    for covariance_type in ("full", "tied", "spherical", "diag"):
        bic = GaussianMixture(n_components = k, n_init = 10, \
                              covariance_type = covariance_type, \
                              random_state = 42).fit(X).bic(X)
        if bic < min_bic:
            min_bic = bic
            best_k = k
            best_covariance_type = covariance_type
display("Best k:", best_k, "Best covariance type:", best_covariance_type)
# Out:
# 'Best k:'
# 3
# 'Best covariance type:'
# 'full'

# %% [markdown]
# ## Likelihood Function
# * Probability: Given a statistical model with parameters $\theta$, how plausible a future outcome $x$ is
#     * PDF is a function of $x$ with $\theta$ fixed
#     * The integral of a PDF is 1
# * Likelihood: After an outcome $x$ is known, how plausible a set of parameters $\theta$ is
#     * Likelihood function is a function of $\theta$ with $x$ fixed
#     * The integral of a likelihood function counld be any positive value

# %%
from scipy.stats import norm
from matplotlib.patches import Polygon

xx = np.linspace(-6, 4, 101)
ss = np.linspace(1, 2, 101)
XX, SS = np.meshgrid(xx, ss)
ZZ = 2 * norm.pdf(XX - 1.0, 0, SS) + norm.pdf(XX + 4.0, 0, SS)
ZZ = ZZ / ZZ.sum(axis = 1) / (xx[1] - xx[0])
x_idx = 85
s_idx = 30

plt.figure(figsize=(8, 4.5))
plt.subplot(221)
plt.contourf(XX, SS, ZZ, cmap="GnBu")
plt.plot([-6, 4], [ss[s_idx], ss[s_idx]], "k-", linewidth=2)
plt.plot([xx[x_idx], xx[x_idx]], [1, 2], "b-", linewidth=2)
plt.xlabel(r"$x$")
plt.ylabel(r"$\theta$", fontsize=14, rotation=0)
plt.title(r"Model $f(x; \theta)$", fontsize=14)

plt.subplot(222)
plt.plot(ss, ZZ[:, x_idx], "b-")
max_idx = np.argmax(ZZ[:, x_idx])
max_val = np.max(ZZ[:, x_idx])
plt.plot(ss[max_idx], max_val, "r.")
plt.plot([ss[max_idx], ss[max_idx]], [0, max_val], "r:")
plt.plot([0, ss[max_idx]], [max_val, max_val], "r:")
plt.text(1.01, max_val + 0.005, r"$\hat{L}$", fontsize=14)
plt.text(ss[max_idx]+ 0.01, 0.055, r"$\hat{\theta}$", fontsize=14)
plt.text(ss[max_idx]+ 0.01, max_val - 0.012, r"$Max$", fontsize=12)
plt.axis([1, 2, 0.05, 0.15])
plt.xlabel(r"$\theta$", fontsize=14)
plt.grid(True)
plt.text(1.99, 0.135, r"$=f(x=2.5; \theta)$", fontsize=14, ha="right")
plt.title(r"Likelihood function $\mathcal{L}(\theta|x=2.5)$", fontsize=14)

plt.subplot(223)
plt.plot(xx, ZZ[s_idx], "k-")
plt.axis([-6, 4, 0, 0.25])
plt.xlabel(r"$x$", fontsize=14)
plt.grid(True)
plt.title(r"PDF $f(x; \theta=1.3)$", fontsize=14)
verts = [(xx[41], 0)] + list(zip(xx[41:81], ZZ[s_idx, 41:81])) + [(xx[80], 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
plt.gca().add_patch(poly)

plt.subplot(224)
plt.plot(ss, np.log(ZZ[:, x_idx]), "b-")
max_idx = np.argmax(np.log(ZZ[:, x_idx]))
max_val = np.max(np.log(ZZ[:, x_idx]))
plt.plot(ss[max_idx], max_val, "r.")
plt.plot([ss[max_idx], ss[max_idx]], [-5, max_val], "r:")
plt.plot([0, ss[max_idx]], [max_val, max_val], "r:")
plt.axis([1, 2, -2.4, -2])
plt.xlabel(r"$\theta$", fontsize=14)
plt.text(ss[max_idx]+ 0.01, max_val - 0.05, r"$Max$", fontsize=12)
plt.text(ss[max_idx]+ 0.01, -2.39, r"$\hat{\theta}$", fontsize=14)
plt.text(1.01, max_val + 0.02, r"$\log \, \hat{L}$", fontsize=14)
plt.grid(True)
plt.title(r"$\log \, \mathcal{L}(\theta|x=2.5)$", fontsize=14)

save_fig("likelihood_function_plot")
plt.show()
# Out:
# Saving figure likelihood_function_plot

# %% [markdown]
# ## Variational Bayesian Gaussian Mixtures
# * `BayesianGaussianMixture` will push unnecessary clusters' weights to zero

# %%
from sklearn.mixture import BayesianGaussianMixture
bgm = BayesianGaussianMixture(n_components = 10, n_init = 10, random_state = 42)
display(bgm.fit(X))
display(np.round(bgm.weights_, 2))
plt.figure(figsize = (8, 5))
plot_gaussian_mixture(bgm, X)
plt.show()
# Out:
# BayesianGaussianMixture(covariance_prior=None, covariance_type='full',
#                         degrees_of_freedom_prior=None, init_params='kmeans',
#                         max_iter=100, mean_precision_prior=None,
#                         mean_prior=None, n_components=10, n_init=10,
#                         random_state=42, reg_covar=1e-06, tol=0.001, verbose=0,
#                         verbose_interval=10, warm_start=False,
#                         weight_concentration_prior=None,
#                         weight_concentration_prior_type='dirichlet_process')
# array([0.4 , 0.21, 0.4 , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  ])

# %%
# Make prior assumptions of cluster densities
nn = 73
bgm_low = BayesianGaussianMixture(n_components = 10, max_iter = 1000, n_init = 1, \
                                  weight_concentration_prior = 0.01, \
                                  random_state = 42).fit(X[: nn])
bgm_high = BayesianGaussianMixture(n_components = 10, max_iter = 1000, n_init = 1, \
                                   weight_concentration_prior = 10000, \
                                   random_state = 42).fit(X[: nn])
display("Low conc.:", np.round(bgm_low.weights_, 2), \
        "High conc.:", np.round(bgm_high.weights_, 2))
plt.figure(figsize = (9, 4))
plt.subplot(121)
plot_gaussian_mixture(bgm_low, X[:nn])
plt.title("weight_concentration_prior = 0.01", fontsize=14)

plt.subplot(122)
plot_gaussian_mixture(bgm_high, X[:nn], show_ylabels=False)
plt.title("weight_concentration_prior = 10000", fontsize=14)

save_fig("mixture_concentration_prior_plot")
plt.show()
# Out:
# 'Low conc.:'
# array([0.52, 0.48, 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  ])
# 'High conc.:'
# array([0.01, 0.18, 0.27, 0.11, 0.01, 0.01, 0.01, 0.01, 0.37, 0.01])
# Saving figure mixture_concentration_prior_plot

# %%
from sklearn.datasets import make_moons
X_moons, y_moons = make_moons(n_samples = 1000, noise = 0.05, random_state = 42)
bgm = BayesianGaussianMixture(n_components = 10, n_init = 10, random_state = 42)
display(bgm.fit(X_moons))
plt.figure(figsize=(9, 3.2))

plt.subplot(121)
plot_data(X_moons)
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)

plt.subplot(122)
plot_gaussian_mixture(bgm, X_moons, show_ylabels=False)

save_fig("moons_vs_bgm_plot")
plt.show()
# Out:
# BayesianGaussianMixture(covariance_prior=None, covariance_type='full',
#                         degrees_of_freedom_prior=None, init_params='kmeans',
#                         max_iter=100, mean_precision_prior=None,
#                         mean_prior=None, n_components=10, n_init=10,
#                         random_state=42, reg_covar=1e-06, tol=0.001, verbose=0,
#                         verbose_interval=10, warm_start=False,
#                         weight_concentration_prior=None,
#                         weight_concentration_prior_type='dirichlet_process')
# Saving figure moons_vs_bgm_plot

# %% [markdown]
# ## KL divergence
# Please check the book page 272.

# %% [markdown]
# ## Other Anomaly and Novelty Detection Algos
# * Fast-MCD (minimum covariance determinant), used by EllipticEnvelope
# * Isolation Forest, total random generated tree that separate all instances, anomalies has lower depths
# * Local Outlier Factor (LOF), an anomaly has larger mean distance from its KNN
# * One-class SVM, better suits for novelty detection. Tries to separate the instances in high-dimensional space from the origin space. (?)
